# %%
# coding: utf-8
import re
import time
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from multiprocessing import Pool

# %%
request_headers = {
    'Accept-Language': 'en-US,en;q=0.5',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:40.0) Gecko/20100101 Firefox/40.0',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8',
    'Connection': 'keep-alive'
}

def _build_bs4_from_url(url):
    res = requests.get(url)
    if res.status_code == 200:
        return BeautifulSoup(res.text, 'html.parser')
    print(res.status_code)
    return None

def get_argus_price(version, year):
    url_argus = 'https://www.lacentrale.fr/cote-auto-{}-{}-{}-{}.html'
    url = url_argus.format('renault', 'zoe', version.replace(' ', '+'), year)
    soup = _build_bs4_from_url(url)
    argus = soup.find('span', class_='jsRefinedQuot')
    if argus is not None:
        argus = argus.getText().strip().replace(' ', '')
    else:
        argus = np.NaN
    return argus

def _clean_data(df):
    reg = r'\D*(\d+)\D*(\d*)\D(\d*).*'
    df['KM'] = df['KM'].apply(lambda x: re.sub(reg, r'\1\2', str(x)))
    df['PRICE'] = df['PRICE'].apply(lambda x: re.sub(reg, r'\1\2', str(x)))
    df['PRICE'] = pd.to_numeric(df['PRICE'], errors='coerce')
    df['KM'] = pd.to_numeric(df['KM'], errors='coerce')
    df['ARGUS'] = pd.to_numeric(df['ARGUS'], errors='coerce')
    return df

def scan_lacentrale(region):
    df = pd.DataFrame(columns=['VERSION', 'YEAR', 'KM', 'SELLER', 'PRICE', 'ARGUS'])
    url_prefix = 'https://www.lacentrale.fr/'
    url_scan = 'listing?makesModelsCommercialNames=RENAULT%3AZOE&regions={}&page={}'
    page = 1
    i = 1
    soup = _build_bs4_from_url(url_prefix+url_scan.format(region, page))
    total = int(soup.find('span', class_='numAnn').getText())
    while i < total:
        table = soup.find_all(class_='subContRight')
        if table:
            for car in table:
                version = car.find('span', class_='version').getText()
                year = car.find('div', class_='fieldYear').getText()
                km = car.find('div', class_='fieldMileage').getText()
                price = car.find('div', class_='fieldPrice').getText()
                seller = car.find('p', class_='typeSeller').getText()
                argus = get_argus_price(version.lower(), year)
                df.loc[i] = [version, year, km, seller, price, argus]
                i += 1
        page += 1
        soup = _build_bs4_from_url(url_prefix+url_scan.format(region, page))
    df = _clean_data(df)
    return df

def main():
    regions = ['FR-IDF', 'FR-PAC', 'FR-NAQ']
    df = pd.DataFrame(columns=['VERSION', 'YEAR', 'KM', 'SELLER' 'PRICE', 'ARGUS'])

    start2 = time.time()
    p = Pool(3)
    df = pd.concat(p.map(scan_lacentrale, regions), axis=0, ignore_index=True)
    end2 = time.time()
    print(f'Time with multiprocessing {end2-start2:.2f} s')

    df['COTE'] = '+'
    df['COTE'].where(df['PRICE'] > df['ARGUS'], '-', inplace=True)
    print(df)
    df.to_json('centrale.json', orient='records', lines=True)
    # df.to_csv('centrale.csv', sep=';', index=False)


if __name__ == '__main__':
    main()
# Out:
# Time with multiprocessing 72.68 s
#                            VERSION  YEAR     KM         SELLER  PRICE  \
# 0         Q90 INTENS CHARGE RAPIDE  2015  29100  Professionnel   9600
# 1                         Q90 LIFE  2015  14513  Professionnel   8990
# 2           Q90 LIFE CHARGE RAPIDE  2015  52580  Professionnel   6990
# 3                         Q90 LIFE  2015  30486  Professionnel   8290
# 4                          Q90 ZEN  2015  55756  Professionnel   7490
# 5           Q90 LIFE CHARGE RAPIDE  2014   9090  Professionnel   9100
# 6           Q90 LIFE CHARGE RAPIDE  2015  14543  Professionnel   7990
# 7           Q90 LIFE CHARGE RAPIDE  2015  23129  Professionnel   8990
# 8                         Q90 LIFE  2015  52580  Professionnel   6990
# 9            Q90 ZEN CHARGE RAPIDE  2015  31013  Professionnel   8800
# 10           Q90 ZEN CHARGE RAPIDE  2015  19822  Professionnel   9990
# 11                         Q90 ZEN  2015  30434  Professionnel   9690
# 12                        Q90 LIFE  2015  15769  Professionnel   8990
# 13                        Q90 LIFE  2015  16182  Professionnel   9200
# 14                        Q90 LIFE  2015  22435  Professionnel   8490
# 15              LIFE CHARGE RAPIDE  2014  47802  Professionnel   6690
# 16                         Q90 ZEN  2015  11115  Professionnel  12540
# 17                        Q90 LIFE  2014  63593  Professionnel   8840
# 18          Q90 LIFE CHARGE RAPIDE  2015  24919  Professionnel   8230
# 19                         Q90 ZEN  2014  16150  Professionnel  10240
# 20          Q90 LIFE CHARGE RAPIDE  2014  13242  Professionnel  10050
# 21          Q90 LIFE CHARGE RAPIDE  2015  59133  Professionnel   8670
# 22                        Q90 LIFE  2016  17111  Professionnel   9030
# 23           Q90 ZEN CHARGE RAPIDE  2015  43773  Professionnel   9590
# 24                        Q90 LIFE  2014  20247  Professionnel  11310
# 25                  (2) R90 INTENS  2018   8610  Professionnel  14940
# 26            INTENS CHARGE RAPIDE  2014  19845  Professionnel  10970
# 27                        Q90 LIFE  2016  15596  Professionnel   9200
# 28                        Q90 LIFE  2016  18567  Professionnel  11140
# 29                        Q90 LIFE  2016  56890  Professionnel   7890
# ..                             ...   ...    ...            ...    ...
# 259                           LIFE  2017  16660  Professionnel  12240
# 260           INTENS CHARGE RAPIDE  2014  19582  Professionnel  11610
# 261                       Q90 LIFE  2014  33719  Professionnel  11010
# 262                         INTENS  2014  38308  Professionnel  11640
# 263           INTENS CHARGE RAPIDE  2016  63010  Professionnel  11740
# 264                       Q90 LIFE  2016  35575  Professionnel  11480
# 265         Q90 LIFE CHARGE RAPIDE  2014  40314  Professionnel  11220
# 266                       Q90 LIFE  2016  40538  Professionnel  11160
# 267  LIFE CHARGE RAPIDE GAMME 2017  2015  11178  Professionnel  12070
# 268                R90 LIFE TYPE 2  2017  45408  Professionnel  11310
# 269         Q90 LIFE CHARGE RAPIDE  2015  53548  Professionnel  12160
# 270  Q90 LIFE CHARGE RAPIDE TYPE 2  2016  12152  Professionnel  13620
# 271                           LIFE  2015  14548  Professionnel  11170
# 272                       Q90 LIFE  2016  24466  Professionnel  11380
# 273                       R75 LIFE  2019    106  Professionnel  15900
# 274           INTENS CHARGE RAPIDE  2012  43080  Professionnel   9180
# 275             LIFE CHARGE RAPIDE  2014  95138  Professionnel   7750
# 276                       Q90 LIFE  2014  40645  Professionnel  11220
# 277                       Q90 LIFE  2013  41294  Professionnel  10960
# 278           INTENS CHARGE RAPIDE  2016  18715  Professionnel  13120
# 279         Q90 LIFE CHARGE RAPIDE  2014  24374  Professionnel  10720
# 280                           LIFE  2015  11316  Professionnel  10480
# 281                           LIFE  2017  12141  Professionnel  12990
# 282                     INTENS R90  2017    109  Professionnel  25980
# 283                           LIFE  2014  61151  Professionnel  10050
# 284                   ZEN R90 2018  2019    108  Professionnel  24930
# 285           INTENS CHARGE RAPIDE  2013  21527  Professionnel  11220
# 286              INTENS GAMME 2017  2018  11279  Professionnel  16090
# 287            R75 LIFE GAMME 2017  2019   4212  Professionnel  21490
# 288                       R75 LIFE  2017    100  Professionnel  26120
#
#        ARGUS COTE
# 0    12205.0    -
# 1    11151.0    -
# 2     9891.0    -
# 3    11151.0    -
# 4    11066.0    -
# 5     9554.0    -
# 6     9891.0    -
# 7     9891.0    -
# 8    11151.0    -
# 9    10340.0    -
# 10   10340.0    -
# 11   11066.0    -
# 12   11151.0    -
# 13   11151.0    -
# 14   11151.0    -
# 15       NaN    -
# 16   11066.0    +
# 17    9760.0    -
# 18    9891.0    -
# 19   10024.0    +
# 20    9554.0    +
# 21    9891.0    -
# 22   12007.0    -
# 23   10340.0    -
# 24    9760.0    +
# 25   15728.0    -
# 26       NaN    -
# 27   12007.0    -
# 28   12007.0    -
# 29   12007.0    -
# ..       ...  ...
# 259      NaN    -
# 260      NaN    -
# 261   9760.0    +
# 262      NaN    -
# 263      NaN    -
# 264  12007.0    -
# 265   9554.0    +
# 266  12007.0    -
# 267      NaN    -
# 268  12239.0    -
# 269   9891.0    +
# 270  11926.0    +
# 271      NaN    -
# 272  12007.0    -
# 273      NaN    -
# 274      NaN    -
# 275      NaN    -
# 276   9760.0    +
# 277   8156.0    +
# 278      NaN    -
# 279   9554.0    +
# 280      NaN    -
# 281      NaN    -
# 282      NaN    -
# 283      NaN    -
# 284      NaN    -
# 285      NaN    -
# 286      NaN    -
# 287      NaN    -
# 288      NaN    -
#
# [289 rows x 7 columns]
