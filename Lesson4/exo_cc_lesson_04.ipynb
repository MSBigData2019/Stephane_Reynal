# %%
# coding: utf-8
import re
import sys
import json
import requests
import pandas as pd

# %%
def load_data_para(url):
    res = requests.get(url)
    res_json = json.loads(res.text)
    return pd.read_json(res.text)


def read_info(code):
    url = f'https://www.open-medicaments.fr/api/v1/medicaments/{code}'
    res = requests.get(url).json()
    L = []
    res_substance = res['compositions'][0]['substancesActives'][0]
    L.append(res_substance['denominationSubstance'])
    L.append(res['titulaires'][0])
    L.append(res_substance['dosageSubstance'].split()[0].replace(',', '.'))
    L.append(res_substance['dosageSubstance'].split()[1])
    L.append(res['formePharmaceutique'])
    L.append(res['etatCommercialisation'])
    L.append(res['presentations'][0]['prix'])
    return L[0], L[1], L[2], L[3], L[4], L[5], L[6]

def get_info(df):
    L = ['Nom', 'Labo', 'dosage', 'unite', 'forme', 'commercialisation', 'prix']
    df[L[0]], df[L[1]], df[L[2]], df[L[3]], df[L[4]], df[L[5]], df[L[6]] = zip(*df['codeCIS'].apply(lambda x: read_info(str(x))))
    return df

def dosage_mg(df):
    df['mul'] = 1000
    df['mul'] = df['mul'].where(df['unite'] == 'g', 1)
    df['dosage'] = df['dosage'].fillna(0).astype(float)*df['mul']
    df.rename(columns={'dosage': 'dosage(mg)'}, inplace=True)
    df.drop(['mul', 'unite'], axis=1, inplace=True)
    return df

def by_using_the_full_api(url):
    df = load_data_para(url)
    del df['denomination']
    df = get_info(df)
    df_clean = dosage_mg(df)
    return df_clean

def by_regex(url):
    df = load_data_para(url)
    reg = r'([\w]*)\s([\D]*)\s(\d+)\s(.*),(.*)'
    denom = df['denomination']
    df_temp = denom.str.extract(reg)
    df_temp.rename(columns={0:'Nom', 1:'Labo', 2:'dosage',
                            3:'unite', 4:'forme'}, inplace=True)
    df_temp = dosage_mg(df_temp)
    df_clean = pd.concat([df['codeCIS'], df_temp], axis=1)
    return df_clean

def main():
    url = 'https://open-medicaments.fr/api/v1/medicaments?query=paracetamol'
    print(f"Using regex from {url}")
    df1 = by_regex(url)
    print(df1)
    print(f"Search more information with the api")
    df2 = by_using_the_full_api(url)
    print(df2)

if __name__ == '__main__':
    main()
# Out:
# Using regex from https://open-medicaments.fr/api/v1/medicaments?query=paracetamol
#      codeCIS          Nom             Labo  dosage(mg)                   forme
# 0   67445776  PARACETAMOL            ZYDUS       500.0                  gélule
# 1   62721886  PARACETAMOL       RATIOPHARM      1000.0                comprimé
# 2   62772966  PARACETAMOL               EG      1000.0                comprimé
# 3   67034675  PARACETAMOL           SANDOZ       500.0                  gélule
# 4   61223352  PARACETAMOL       RATIOPHARM       500.0                  gélule
# 5   65085849  PARACETAMOL            ARROW       500.0   comprimé effervescent
# 6   61754805  PARACETAMOL             AHCL      1000.0   comprimé effervescent
# 7   60777377  PARACETAMOL           ISOMED       500.0   comprimé effervescent
# 8   62502166  PARACETAMOL       RATIOPHARM       500.0        comprimé sécable
# 9   68830091  PARACETAMOL         EVOLUGEN      1000.0        comprimé sécable
# 10  64500406  PARACETAMOL  ZENTIVA CONSEIL       500.0                comprimé
# 11  64503085  PARACETAMOL         CRISTERS       500.0                comprimé
# 12  65418129  PARACETAMOL          RANBAXY       500.0                  gélule
# 13  61134042  PARACETAMOL          RANBAXY      1000.0                comprimé
# 14  66400810  PARACETAMOL          ZENTIVA       500.0                comprimé
# 15  65881579  PARACETAMOL            ZYDUS      1000.0                comprimé
# 16  65827097  PARACETAMOL            ZYDUS       500.0                comprimé
# 17  65335982  PARACETAMOL               EG       500.0                  gélule
# 18  61960431  PARACETAMOL              RPG       500.0                comprimé
# 19  68249079  PARACETAMOL             TEVA       500.0                comprimé
# Search more information with the api
#      codeCIS          Nom                                 Labo  dosage(mg)  \
# 0   67445776  PARACÉTAMOL                         ZYDUS FRANCE       500.0
# 1   62721886  PARACÉTAMOL                           TEVA SANTE      1000.0
# 2   62772966  PARACÉTAMOL  EG LABO - LABORATOIRES EUROGENERICS      1000.0
# 3   67034675  PARACÉTAMOL                               SANDOZ       500.0
# 4   61223352  PARACÉTAMOL                           TEVA SANTE       500.0
# 5   65085849  PARACÉTAMOL                     ARROW GENERIQUES       500.0
# 6   61754805  PARACÉTAMOL      ACCORD HEALTHCARE (ROYAUME UNI)      1000.0
# 7   60777377  PARACÉTAMOL                           TEVA SANTE       500.0
# 8   62502166  PARACÉTAMOL               RATIOPHARM (ALLEMAGNE)       500.0
# 9   68830091  PARACÉTAMOL                           EVOLUPHARM      1000.0
# 10  64500406  PARACÉTAMOL                SANOFI AVENTIS FRANCE       500.0
# 11  64503085  PARACÉTAMOL                             CRISTERS       500.0
# 12  65418129  PARACÉTAMOL         RANBAXY PHARMACIE GENERIQUES       500.0
# 13  61134042  PARACÉTAMOL         RANBAXY PHARMACIE GENERIQUES      1000.0
# 14  66400810  PARACÉTAMOL                SANOFI AVENTIS FRANCE       500.0
# 15  65881579  PARACÉTAMOL                         ZYDUS FRANCE      1000.0
# 16  65827097  PARACÉTAMOL                         ZYDUS FRANCE       500.0
# 17  65335982  PARACÉTAMOL  EG LABO - LABORATOIRES EUROGENERICS       500.0
# 18  61960431  PARACÉTAMOL         RANBAXY PHARMACIE GENERIQUES       500.0
# 19  68249079  PARACÉTAMOL                           TEVA SANTE       500.0
#
#                        forme  commercialisation  prix
# 0                     gélule               True   2.1
# 1                   comprimé              False   2.1
# 2                   comprimé               True   2.1
# 3                     gélule               True   2.1
# 4                     gélule               True   2.1
# 5   comprimé effervescent(e)               True   2.1
# 6   comprimé effervescent(e)               True   2.1
# 7   comprimé effervescent(e)              False   2.1
# 8           comprimé sécable               True   2.1
# 9           comprimé sécable              False  None
# 10                  comprimé              False  None
# 11                  comprimé               True   2.1
# 12                    gélule               True   2.1
# 13                  comprimé              False  None
# 14                  comprimé               True  None
# 15                  comprimé               True   2.1
# 16                  comprimé               True   2.1
# 17                    gélule               True   2.1
# 18                  comprimé              False  None
# 19                  comprimé               True   2.1
